# %%
pip install plotly
pip install wordcloud
pip install plottable
pip install seaborn
pip install matplotlib-venn
# Out:
# Requirement already satisfied: plotly in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from plotly) (8.4.2)
# Requirement already satisfied: packaging in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from plotly) (24.1)
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/300.6 kB 960.0 kB/s eta 0:00:01
#    ------------------- -------------------- 143.4/300.6 kB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 235.5/300.6 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 300.6/300.6 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Collecting plottable
#   Downloading plottable-0.1.5-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: matplotlib in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from plottable) (3.8.4)
# Requirement already satisfied: numpy in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from plottable) (1.26.4)
# Requirement already satisfied: pandas in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from plottable) (2.2.2)
# Requirement already satisfied: Pillow in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from plottable) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->plottable) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from pandas->plottable) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from pandas->plottable) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->plottable) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->plottable) (1.16.0)
# Downloading plottable-0.1.5-py3-none-any.whl (24 kB)
# Installing collected packages: plottable
# Successfully installed plottable-0.1.5
# Requirement already satisfied: seaborn in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.0.tar.gz (40 kB)
#      ---------------------------------------- 0.0/40.2 kB ? eta -:--:--
#      ---------------------------------------- 40.2/40.2 kB 1.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.8.4)
# Requirement already satisfied: numpy in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.26.4)
# Requirement already satisfied: scipy in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.0-py3-none-any.whl size=45304 sha256=45ad815915351e9a825267efed5d09a3780029963e74c8dfeeabdb9688a77d84
#   Stored in directory: c:\users\yulii\appdata\local\pip\cache\wheels\5c\3e\90\a7cba268effb0fdde2ae3f171f3b819bb5d5c6e96c80e1aeb7
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-1.1.0

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('white')

sns.lineplot(data=tips,
             x='total_bill',
             y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tipgraph = sns.lineplot(data = tips,
                        x='total_bill',
                        y ='tip')
tipgraph.set(title = 'Tips vs Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10,3))

tipgraph = sns.lineplot(data = tips,
                        x='total_bill',
                        y = 'tip',
                        color = 'hotpink',
                        linestyle = '--',
                        linewidth = 3,
                        marker = 'o',
                        markerfacecolor = 'indigo')

tipgraph.set(title = 'Tips vs Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10,3))

fakegraph = sns.lineplot(data = tips,
                        x='total_bill',
                        y = 'tip',
                        color = 'red',
                        linestyle = '--',
                        linewidth = 3,
                        marker = 'o',
                        markerfacecolor = 'indigo')

# %%
tipgraph = sns.scatterplot(data = tips,
                        x='total_bill',
                        y = 'tip',
                        style = 'time',
                        hue = 'day',
                        palette = ['purple',
                                   'hotpink',
                                   'deepskyblue',
                                   'yellowgreen'])

tipgraph.set(title = 'Tips vs Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(data = tips,
             hue = 'day')

# %%
sns.relplot(data = tips,
           x = "total_bill",
           y = "tip",
           hue = "sex",
           col = "day",
           kind = "scatter",
           col_wrap = 2)

# %% [markdown]
# Class activities:
#
# Difference: 1st visualization focuses on average ratings rather than the frequency of specific words or phrases.
#
# 1st.
# Pros: Clear comparison of average ratings, sample size context.
# Cons: Lack of detail on rating distribution, focuses only on mean values.
# 2nd.
# Pros: Detailed analysis of language use.
# Cons: May be more complex to interpret, doesn't provide direct comparison of rating values

# %%
import plotly.graph_objects as go
x1 = np.array(["Luffy","Zoro","Nami","Usoop","Sanji"])
y1 = np.array([110,180,240,99,220])

# %%
graph = go.Figure()

graph.add_trace(go.Bar(x=x1,y=y1))

graph.update_layout(title = "Pirate Scores",
                    xaxis_title = "Pirates",
                    yaxis_title = "Score")

# %%
graph = go.Figure()

graph.add_trace(go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    marker = dict(
        size = 15,
        color = 'hotpink',
        opacity = 1,
        line = dict(width = 5, color = 'purple')
    )
))

graph.update_layout(
    title = 'Interactive Pirate Plot',
    xaxis_title = 'Pirates',
    yaxis_title = 'Scores',
    width = 500,
    height = 500
)

# %%
#!pip install wordcloud
from wordcloud import WordCloud

df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
                 on_bad_lines = 'skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
text = " ".join(each for each in df.quote)

wordcloud = WordCloud(background_color='white',
                      colormap='inferno').generate(text)

fig, ax = plt.subplots(figsize = (7,3))
ax.imshow(wordcloud,
          interpolation = 'bilinear')
ax.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# !pip install matplotlib-venn
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# Out:
# Requirement already satisfied: matplotlib-venn in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.8.4)
# Requirement already satisfied: numpy in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.26.4)
# Requirement already satisfied: scipy in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\yulii\soft\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])

diagram = venn2([A,B],
                set_labels = ("Fruits","Pies"),
                set_colors = ("blue", "red"),
                alpha = 0.5
                )

diagram.get_label_by_id("10").set_text("\n".join(A-B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B-A))
